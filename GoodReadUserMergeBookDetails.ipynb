# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import warnings
warnings.filterwarnings('ignore')

# %%
Book = pd.read_json('BookDetails/goodreads_books_children.json', lines = True)

# %%
Book.drop("similar_books", axis = 1, inplace = True)

# %%
Book
# Out:
#               isbn  text_reviews_count    series country_code language_code  \
# 0       1599150603                   7        []           US
# 1       1934876569                   6  [151854]           US
# 2       0590417010                 193        []           US           eng
# 3       0915190575                   4        []           US
# 4       1416904999                   4        []           US
# ...            ...                 ...       ...          ...           ...
# 124077                               1        []           US
# 124078                               7        []           US         en-GB
# 124079  0061960314                  13        []           US
# 124080  0689852959                   1        []           US
# 124081  0765197456                   6        []           US
#
#                                           popular_shelves        asin  \
# 0       [{'count': '56', 'name': 'to-read'}, {'count':...
# ...

# %%
data = pd.read_csv('GoodReadCSV/UserBookInteraction.csv')

# %%
data.shape
# Out:
# (1378033, 6)

# %%
UniqueBook=data['book_id'].unique()

# %%
UniqueBook.shape
# Out:
# (25475,)

# %%
bookId_dataframe=pd.DataFrame({'book_id':UniqueBook})

# %%
merged_book = bookId_dataframe.merge(Book, how='inner', left_on='book_id', right_on='book_id')

# %%
merged_book
# Out:
#       book_id        isbn  text_reviews_count     series country_code  \
# 0       10365  0375806814                7868         []           US
# 1       10959  1857993284                4324         []           US
# 2           5  043965548X               28561   [162083]           US
# 3    11387515  0375869026               31536   [632090]           US
# 4      324277  0064410129                1572   [154017]           US
# ..        ...         ...                 ...        ...          ...
# 450  32940857  0316355895                 428  [1001640]           US
# 451  13429616  0547634552                 198         []           US
# 452  15797936  0736481370                 169   [446563]           US
# 453    852594  1405208708                  67   [155739]           US
# 454  25685200  0062238647                 214         []           US
#
#     language_code                                    popular_shelves asin  \
# ...

# %%
merged_book.to_csv('GoodReadCSV/children.csv')

# %%
data = pd.read_csv('GoodReadCSV/UserBookInteraction.csv')
