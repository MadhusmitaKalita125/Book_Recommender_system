# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import warnings
warnings.filterwarnings('ignore')

# %%
children = pd.read_csv('GoodReadCSV/NewCSV/children.csv')

# %%
comics_graphic=pd.read_csv('GoodReadCSV/NewCSV/comics_graphic.csv')

# %%
fantasy_paranormal=pd.read_csv('GoodReadCSV/NewCSV/fantasy_paranormal.csv')

# %%
history_biography=pd.read_csv('GoodReadCSV/NewCSV/history_biography.csv')

# %%
mystery_thriller_crime=pd.read_csv('GoodReadCSV/NewCSV/mystery_thriller_crime.csv')

# %%
poetry=pd.read_csv('GoodReadCSV/NewCSV/poetry.csv')

# %%
romance=pd.read_csv('GoodReadCSV/NewCSV/romance.csv')

# %%
young_adult=pd.read_csv('GoodReadCSV/NewCSV/young_adult.csv')

# %%
print(children.shape)
print(comics_graphic.shape)
print(fantasy_paranormal.shape)
print(history_biography.shape)
print(mystery_thriller_crime.shape)
print(poetry.shape)
print(romance.shape)
print(young_adult.shape)
# Out:
# (455, 30)
# (962, 30)
# (8437, 30)
# (2253, 30)
# (2694, 30)
# (35, 30)
# (9057, 30)
# (6091, 30)

# %%
Book_D=[children,comics_graphic,fantasy_paranormal,history_biography,mystery_thriller_crime,poetry,romance,young_adult]

# %%
result = pd.concat(Book_D)

# %%
result
# Out:
#       Unnamed: 0   book_id        isbn  text_reviews_count      series  \
# 0              0     10365   375806814                7868          []
# 1              1     10959  1857993284                4324          []
# 2              2         5  043965548X               28561  ['162083']
# 3              3  11387515   375869026               31536  ['632090']
# 4              4    324277    64410129                1572  ['154017']
# ...          ...       ...         ...                 ...         ...
# 6086        6086   8129464  014132693X                 229  ['205564']
# 6087        6087  24907344  1442426756                  68  ['590529']
# 6088        6088  10860716  1554683394                  78  ['309404']
# 6089        6089  28509181  1848454570                  73          []
# 6090        6090  35383830         NaN                  87          []
#
#      country_code language_code  \
# 0              US           NaN
# 1              US           eng
# ...

# %%
result.drop("url", axis = 1, inplace = True)

# %%
result
# Out:
#       Unnamed: 0   book_id        isbn  text_reviews_count country_code  \
# 0              0     10365   375806814                7868           US
# 1              1     10959  1857993284                4324           US
# 2              2         5  043965548X               28561           US
# 3              3  11387515   375869026               31536           US
# 4              4    324277    64410129                1572           US
# ...          ...       ...         ...                 ...          ...
# 6086        6086   8129464  014132693X                 229           US
# 6087        6087  24907344  1442426756                  68           US
# 6088        6088  10860716  1554683394                  78           US
# 6089        6089  28509181  1848454570                  73           US
# 6090        6090  35383830         NaN                  87           US
#
#       average_rating                                               link  \
# ...

# %%
temp = result.groupby(['book_id']).agg('genre':['nunique'])
# Out:
#   File "<ipython-input-51-f096014fd75b>", line 1
#     temp = result.groupby(['book_id']).agg('genre':['nunique'])
#                                                   ^
# SyntaxError: invalid syntax

# %%
UniqueBook=result['book_id'].unique()

# %%
UniqueBook.shape
# Out:
# (22759,)

# %%
temp
# Out:
#           Unnamed: 0  text_reviews_count  average_rating  publication_year  \
# book_id
# 1                 85               22680            4.54            2006.0
# 2                 16               23679            4.47            2004.0
# 3                 44               59856            4.45            1997.0
# 5                  2               28561            4.53            2004.0
# 6                 15               25258            4.53            2002.0
# ...              ...                 ...             ...               ...
# 36196052        8351                  80            4.08               0.0
# 36242916       10936                 140            8.60            4034.0
# 36252773           3                 197            3.99               0.0
# 36307629       11133                 508            9.16            4038.0
# 36328685        1370                 232            4.47               0.0
#
#           ratings_count
# book_id
# ...

# %%
duplicateRowsDF = result[result.duplicated(['book_id'])]

# %%
duplicateRowsDF
# Out:
#       Unnamed: 0   book_id        isbn  text_reviews_count country_code  \
# 182          182  35669801  1941302459                  88           US
# 196          196  28503853  1101918713                 496           US
# 645          645    300946   968876838                 397           US
# 710          710  20718289  1935179624                 589           US
# 725          725   8044557   811874559                1221           US
# ...          ...       ...         ...                 ...          ...
# 6081        6081  13081309         NaN                  37           US
# 6083        6083   8686026   758253389                 156           US
# 6085        6085  13616048         NaN                  65           US
# 6087        6087  24907344  1442426756                  68           US
# 6089        6089  28509181  1848454570                  73           US
#
#       average_rating                                               link  \
# ...

# %%
duplicateRowsDF
# Out:
#       Unnamed: 0   book_id        isbn  text_reviews_count country_code  \
# 182          182  35669801  1941302459                  88           US
# 196          196  28503853  1101918713                 496           US
# 645          645    300946   968876838                 397           US
# 710          710  20718289  1935179624                 589           US
# 725          725   8044557   811874559                1221           US
# ...          ...       ...         ...                 ...          ...
# 6081        6081  13081309         NaN                  37           US
# 6083        6083   8686026   758253389                 156           US
# 6085        6085  13616048         NaN                  65           US
# 6087        6087  24907344  1442426756                  68           US
# 6089        6089  28509181  1848454570                  73           US
#
#       average_rating                                               link  \
# ...

# %%
result[result["book_id"]==13616048]
# Out:
#       Unnamed: 0   book_id isbn  text_reviews_count country_code  \
# 8428        8428  13616048  NaN                  65           US
# 6085        6085  13616048  NaN                  65           US
#
#       average_rating                                               link  \
# 8428            4.16  https://www.goodreads.com/book/show/13616048-s...
# 6085            4.16  https://www.goodreads.com/book/show/13616048-s...
#
#                                      authors   publisher  publication_year  \
# 8428  [{'author_id': '4629194', 'role': ''}]  Kensington            2012.0
# 6085  [{'author_id': '4629194', 'role': ''}]  Kensington            2012.0
#
#                                               image_url  ratings_count  \
# 8428  https://images.gr-assets.com/books/1335322205m...            433
# 6085  https://images.gr-assets.com/books/1335322205m...            433
#
#                       title
# 8428  Spark (Elemental, #2)
# 6085  Spark (Elemental, #2)

# %%
result1=result.groupby(['book_id'], as_index = False).agg({'genre': list})

# %%
result1
# Out:
#         book_id                              genre
# 0             1               [fantasy_paranormal]
# 1             2               [fantasy_paranormal]
# 2             3               [fantasy_paranormal]
# 3             5                         [children]
# 4             6               [fantasy_paranormal]
# ...         ...                                ...
# 22754  36196052                          [romance]
# 22755  36242916       [history_biography, romance]
# 22756  36252773                          [romance]
# 22757  36307629  [fantasy_paranormal, young_adult]
# 22758  36328685           [mystery_thriller_crime]
#
# [22759 rows x 2 columns]

# %%
result3.drop("genre", axis = 1, inplace = True)

# %%
result3.drop_duplicates()
# Out:
#       Unnamed: 0   book_id        isbn  text_reviews_count country_code  \
# 0              0     10365   375806814                7868           US
# 1              1     10959  1857993284                4324           US
# 2              2         5  043965548X               28561           US
# 3              3  11387515   375869026               31536           US
# 4              4    324277    64410129                1572           US
# ...          ...       ...         ...                 ...          ...
# 6086        6086   8129464  014132693X                 229           US
# 6087        6087  24907344  1442426756                  68           US
# 6088        6088  10860716  1554683394                  78           US
# 6089        6089  28509181  1848454570                  73           US
# 6090        6090  35383830         NaN                  87           US
#
#       average_rating                                               link  \
# ...

# %%
result3 = result3.loc[:, ~result3.columns.str.contains('^Unnamed')]

# %%
result3
# Out:
#        book_id        isbn  text_reviews_count country_code  average_rating  \
# 0        10365   375806814                7868           US            4.04
# 1        10959  1857993284                4324           US            3.88
# 2            5  043965548X               28561           US            4.53
# 3     11387515   375869026               31536           US            4.43
# 4       324277    64410129                1572           US            3.97
# ...        ...         ...                 ...          ...             ...
# 6086   8129464  014132693X                 229           US            4.07
# 6087  24907344  1442426756                  68           US            4.17
# 6088  10860716  1554683394                  78           US            3.84
# 6089  28509181  1848454570                  73           US            4.00
# 6090  35383830         NaN                  87           US            4.48
#
# ...

# %%
result4=result3.drop_duplicates()

# %%
result4
# Out:
#        book_id        isbn  text_reviews_count country_code  average_rating  \
# 0        10365   375806814                7868           US            4.04
# 1        10959  1857993284                4324           US            3.88
# 2            5  043965548X               28561           US            4.53
# 3     11387515   375869026               31536           US            4.43
# 4       324277    64410129                1572           US            3.97
# ...        ...         ...                 ...          ...             ...
# 6082  25698127         NaN                 140           US            4.01
# 6084  13919896         NaN                  48           US            3.58
# 6086   8129464  014132693X                 229           US            4.07
# 6088  10860716  1554683394                  78           US            3.84
# 6090  35383830         NaN                  87           US            4.48
#
# ...

# %%
All_book = result4.merge(result1, how='inner', left_on='book_id', right_on='book_id')

# %%
All_book
# Out:
#         book_id        isbn  text_reviews_count country_code  average_rating  \
# 0         10365   375806814                7868           US            4.04
# 1         10959  1857993284                4324           US            3.88
# 2             5  043965548X               28561           US            4.53
# 3      11387515   375869026               31536           US            4.43
# 4        324277    64410129                1572           US            3.97
# ...         ...         ...                 ...          ...             ...
# 22754  25698127         NaN                 140           US            4.01
# 22755  13919896         NaN                  48           US            3.58
# 22756   8129464  014132693X                 229           US            4.07
# 22757  10860716  1554683394                  78           US            3.84
# 22758  35383830         NaN                  87           US            4.48
#
# ...

# %%
All_book.to_csv('GoodReadCSV/Book_detailsall.csv')
